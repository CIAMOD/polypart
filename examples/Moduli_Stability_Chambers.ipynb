# %% [markdown]
# # Counting Stability Chambers of Moduli Spaces
#
# This notebook shows how this partitioning algorithm is useful in **multiple areas of interest**.
# In particular, it has been used in **state-of-the-art research on moduli spaces of parabolic vector bundles**,
# where it allowed us to **count the number of stability chambers** of these moduli spaces with parameters $n$ (number of stability points) and $r$ (rank of vector bundles).
#
# For background see:
#
# > [_A computational analysis of isomorphism classes of moduli spaces of parabolic vector bundles_](https://repositorio.comillas.edu/xmlui/handle/11531/89959)

# %% [markdown]
# ## Step 1. Imports and Setup

# %%
import json
from time import perf_counter


from polypart.ppart import build_partition_tree
from polypart.polytopes import get_simplex
from polypart.arrangements import get_moduli_arrangement
from polypart.io import save_tree, load_tree

# %% [markdown]
# ## Step 2. Build the Polytope
#
# In a moduli space of parabolic vector bundles, the ambient space is a product of simplices of dimension $n(r-1)$.
# We can build this polytope using the predefined function `polypart.polytopes.get_simplex`.
#
# We will study the case of $n=1$ and $r=7$, which gives a simplex of dimension $6$ with $7$ facets.

# %%
n, r = 1, 4
simplex = get_simplex(r - 1)
simplex.extreme()
simplex
# Out:
# Polytope(dim=3, n_ineq=4, n_vertices=4)

# %% [markdown]
# ## Step 3. Generate Hyperplane Arrangement
#
# In the moduli space classification problem, there are some hyperplanes called "stability walls" that partition the parameter space (starting polytope) into chambers, where each chamber represents a different moduli space.
#
# We will generate these hyperplanes using the predefined function `polypart.arrangements.get_moduli_arrangement`, which implements the combinatorial construction of these hyperplanes for the given parameters $n$, $r$, and $d$ (degree of the vector bundles, which we set to $0$ for simplicity).

# %%
hyperplanes = get_moduli_arrangement(n, r, d=0)
print(f"Generated arrangement with {len(hyperplanes)} hyperplanes.")
# Out:
# Generated arrangement with 3 hyperplanes.

# %% [markdown]
# ## Step 4. Build the Partition Tree
#
# We now apply the partitioning algorithm to the polytope and the set of hyperplanes using to different strategies: 'random' and 'v-entropy'. We compare the runtime and the maximum and average depth of the resulting trees.

# %% [markdown]
# - 'Random' strategy: selects hyperplanes randomly at each node.

# %%
from polypart.experiments.stats import print_ppart_stats

start = perf_counter()
tree, n_chambers = build_partition_tree(simplex, hyperplanes, strategy="random")
elapsed = perf_counter() - start
print(f"Found {n_chambers} chambers in {elapsed:.2f} s")


print_ppart_stats(tree)
# Out:
# Found 4 chambers in 0.01 s
# {
#     "total_nodes": 7,
#     "avg_depth": 2.0,
#     "max_depth": 2,
#     "avg_candidates": 0.5714,
#     "avg_inequalities": 3.4286,
#     "avg_vertices": 3.4286
# }

# %% [markdown]
# - 'V-entropy' strategy: maximizes volume entropy (approximated with number of vertices in each sub-polytope).

# %%
start = perf_counter()
tree, n_chambers = build_partition_tree(
    simplex, hyperplanes, strategy="v-entropy", remove_redundancies=True
)
elapsed = perf_counter() - start
print(f"Found {n_chambers} chambers in {elapsed:.2f} s")

print_ppart_stats(tree)
# Out:
# Found 4 chambers in 0.01 s
# {
#     "total_nodes": 7,
#     "avg_depth": 2.25,
#     "max_depth": 3,
#     "avg_candidates": 0.8571,
#     "avg_inequalities": 3.7143,
#     "avg_vertices": 3.7143
# }

# %% [markdown]
# ## Step 6. Saving the Tree (Optional)
#
# The decision tree is very useful in research for identifying **isomorphisms** between stability chambers, since it allows for efficient point location queries, and it also allows for a detailed analysis of the structure of the partition.

# %%
save_tree(tree, f"./data/moduli_tree_n{n}_r{r}.json")

# %%
tree = load_tree(f"./data/moduli_tree_n{n}_r{r}.json")

# Print full tree to verify correct loading
root = tree.root
queue = [root]
while queue:
    node = queue.pop(0)
    print(f"Depth: {node.depth}, Centroid: {node.centroid}")
    for child in node._children:
        queue.append(child)
# Out:
# Depth: 0, Centroid: None
# Depth: 1, Centroid: [mpq(13,24) mpq(5,8) mpq(3,4)]
# Depth: 1, Centroid: None
# Depth: 2, Centroid: None
# Depth: 2, Centroid: [mpq(1,8) mpq(5,24) mpq(3,4)]
# Depth: 3, Centroid: [mpq(1,8) mpq(11,24) mpq(3,4)]
# Depth: 3, Centroid: [mpq(7,24) mpq(5,8) mpq(3,4)]

# %%
from polypart.ftyping import FractionVector
from polypart.morphs import SymmetryGroup, ChamberClassifier
from polypart.moduli import basic_transformation, generate_d_invariant_transformations
from functools import partial
import numpy as np
from polypart.ftyping import as_fraction_vector


def _apply_wrapper(
    vector: FractionVector,
    sigma: tuple[int],
    s: int,
    H: tuple[int],
    n: int,
    r: int,
    d: int,
) -> FractionVector:
    """
    Wrapper that reshapes a flat centroid vector into (1, n, r),
    applies the math, and flattens it back.
    """
    # 1. Reshape flat vector into (1, n, r)
    zeros = as_fraction_vector(np.zeros(n)).reshape(n, 1)
    alphas = np.hstack((zeros, vector.reshape(n, r - 1))).reshape(1, n, r)
    d_arr = np.array([d])

    # 2. Apply math
    new_alphas, _ = basic_transformation(alphas, d_arr, sigma, s, H)

    # 3. Flatten back to vector
    return new_alphas[0, :, 1:].flatten()


def get_moduli_symmetries(n: int, r: int, d: int) -> SymmetryGroup:
    """
    Factory that creates a SymmetryGroup compatible with the generic morph classifier.

    This pre-generates all d-invariant transformations defined by n, r, d
    and wraps them as callables acting on flat vectors.
    """
    transforms = {}

    generator = generate_d_invariant_transformations(n, r, d)

    for i, (sigma, s, H) in enumerate(generator):
        print(f"Generating transformation {i}: sigma={sigma}, s={s}, H={H}")
        # Create a unique name for the transformation (useful for debugging/results)
        name = f"T_{i}_sig{sigma}_s{s}_H{H}"

        # Create a partial function with frozen parameters
        # We must freeze n, r, d, sigma, s, H so they don't change in the loop
        func = partial(_apply_wrapper, sigma=sigma, s=s, H=H, n=n, r=r, d=d)

        transforms[name] = func

    return SymmetryGroup(transforms)


# Create the Symmetry Group using the new moduli adapter
symmetries = get_moduli_symmetries(n, r, 0)

print(f"Generated symmetry group with {len(symmetries)} transformations.")

# Classify
classifier = ChamberClassifier(tree, symmetries)
orbits = classifier.compute_classes(verbose=True)

# Inspect
for orb in orbits:
    print(f"Orbit {orb.id}: {orb.size} chambers")
    print(f"  Stabilizers: {orb.stabilizers}")
# Out:
# Generating transformation 0: sigma=(0,), s=1, H=(0,)
# Generating transformation 1: sigma=(0,), s=-1, H=(0,)
# Generated symmetry group with 2 transformations.
# Classifying 4 chambers...
# 100%|██████████| 4/4 [00:00<00:00, 3978.47it/s]
# Processing new orbit with representative: [mpq(1,8) mpq(5,24) mpq(3,4)]
# Applying transformation: T_0_sig(0,)_s1_H(0,), functools.partial(<function _apply_wrapper at 0x000001EE7FEDC820>, sigma=(0,), s=1, H=(0,), n=1, r=4, d=0)
# Mapped centroid: [mpq(1,8) mpq(5,24) mpq(3,4)]
# Found stabilizer: T_0_sig(0,)_s1_H(0,)
# Applying transformation: T_1_sig(0,)_s-1_H(0,), functools.partial(<function _apply_wrapper at 0x000001EE7FEDC820>, sigma=(0,), s=-1, H=(0,), n=1, r=4, d=0)
# Mapped centroid: [mpq(13,24) mpq(5,8) mpq(3,4)]
# Found iso with centroid: [mpq(13,24) mpq(5,8) mpq(3,4)]
# Processing new orbit with representative: [mpq(7,24) mpq(5,8) mpq(3,4)]
# Applying transformation: T_0_sig(0,)_s1_H(0,), functools.partial(<function _apply_wrapper at 0x000001EE7FEDC820>, sigma=(0,), s=1, H=(0,), n=1, r=4, d=0)
# Mapped centroid: [mpq(7,24) mpq(5,8) mpq(3,4)]
# Found stabilizer: T_0_sig(0,)_s1_H(0,)
# Applying transformation: T_1_sig(0,)_s-1_H(0,), functools.partial(<function _apply_wrapper at 0x000001EE7FEDC820>, sigma=(0,), s=-1, H=(0,), n=1, r=4, d=0)
# Mapped centroid: [mpq(1,8) mpq(11,24) mpq(3,4)]
# Found iso with centroid: [mpq(1,8) mpq(11,24) mpq(3,4)]
# Found 2 isomorphism classes in 0.01s
# Orbit 0: 2 chambers
#   Stabilizers: ['T_0_sig(0,)_s1_H(0,)']
# Orbit 1: 2 chambers
#   Stabilizers: ['T_0_sig(0,)_s1_H(0,)']
